# %%
# %run -i test.py

# %%
run -i test.py

# %%
# %%bash python test.py
# Out:
# UsageError: %%bash is a cell magic, but the cell body is empty.

# %%
ls -a
# Out:
# ./   .ipynb_checkpoints/  dataset/        run_py.sh
# ../  Untitled.ipynb       run_jupyter.sh  test.py

# %%
run -i test.py

# %%
python test.py
# Out:
#   File "<ipython-input-6-83c175a3a2f1>", line 1
#     python test.py
#               ^
# SyntaxError: invalid syntax

# %%
test.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/working/test.py in <module>()
# ----> 1 test.py
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'py'

# %%
run -i test.py

# %%
# %run -i test.py

# %%
import test

# %%
import test

# %%
run -i main
# Out:
# ERROR:root:File `'main.py'` not found.

# %%
run -i test

# %%
run -i test
# Out:
# test

# %%
run -i test
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]
# test

# %%
run -i test
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]
# test

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("./dataset/train.csv", dtype={'Age': np.float64}, )

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ca7e793253ef> in <module>()
# ----> 1 test.head()
#
# NameError: name 'test' is not defined

# %%
test_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f80f5f69a113> in <module>()
# ----> 1 test_data.head()
#
# NameError: name 'test_data' is not defined

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("./dataset/train.csv")

# %%
test = pd.read_csv("./dataset/test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex   ...      Ticket     Fare  Cabin Embarked
# 0          892       3                              Kelly, Mr. James    male   ...      330911   7.8292    NaN        Q
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female   ...      363272   7.0000    NaN        S
# 2          894       2                     Myles, Mr. Thomas Francis    male   ...      240276   9.6875    NaN        Q
# 3          895       3                              Wirz, Mr. Albert    male   ...      315154   8.6625    NaN        S
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   ...     3101298  12.2875    NaN        S
#
# [5 rows x 11 columns]

# %%
test_shape = test.shape

# %%
train_shape = train.shape

# %%
print(test_shape)
# Out:
# (418, 11)

# %%
print(train_shape)
# Out:
# (891, 12)

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Out:
#   File "<ipython-input-14-8ff1ab28de26>", line 1
#     def kesson_table(df):
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
# Out:
#   File "<ipython-input-15-0ae68f2f5f75>", line 1
#     def deficit_table(df):
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
def deficit_table(df):
    null_val = df.isnull().sum()
    percent = 100 * df.isnull().sum() / len(df)
    deficit_table = pd.concat([null_val, percent], axis=1)
    deficit_table_ren_columns = deficit_table.rename(
    columns = {0: '欠損数', 1 : '%'})
    return deficit_table_ren_columns

deficit_table(train)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Survived       0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age          177  19.865320
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        687  77.104377
# Embarked       2   0.224467

# %%
deficit_table(test)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age           86  20.574163
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           1   0.239234
# Cabin        327  78.229665
# Embarked       0   0.000000

# %%
train['Age'] = train["Age"].fillna(train['Age'].median())
train['Embarked'] = train['Embarked'].fillna('s')
deficit_table(train)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Survived       0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age            0   0.000000
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        687  77.104377
# Embarked       0   0.000000

# %%
train['Sex'][train['Sex'] == "male"] = 0
train['Sex'][train['Sex'] == "female"] = 1
train['Embarked'][train['Embarked'] == 'S'] = 0
train['Embarked'][train['Embarked'] == 'C'] = 1
train['Embarked'][train['Embarked'] == 'Q'] = 2
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
train["Sex"][train["Sex"] == "male"] = 0
train["Sex"][train["Sex"] == "female"] = 1
train["Embarked"][train["Embarked"] == "S" ] = 0
train["Embarked"][train["Embarked"] == "C" ] = 1
train["Embarked"][train["Embarked"] == "Q"] = 2
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         0
# 1            2         1       1    ...     71.2833   C85         1
# 2            3         1       3    ...      7.9250   NaN         0
# 3            4         1       1    ...     53.1000  C123         0
# 4            5         0       3    ...      8.0500   NaN         0
#
# [5 rows x 12 columns]

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         0
# 1            2         1       1    ...     71.2833   C85         1
# 2            3         1       3    ...      7.9250   NaN         0
# 3            4         1       1    ...     53.1000  C123         0
# 4            5         0       3    ...      8.0500   NaN         0
# 5            6         0       3    ...      8.4583   NaN         2
# 6            7         0       1    ...     51.8625   E46         0
# 7            8         0       3    ...     21.0750   NaN         0
# 8            9         1       3    ...     11.1333   NaN         0
# 9           10         1       2    ...     30.0708   NaN         1
#
# [10 rows x 12 columns]

# %%
deficit_table(train)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Survived       0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age            0   0.000000
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        687  77.104377
# Embarked       0   0.000000

# %%
test["Age"] = test["Age"].fillna(test["Age"].median())
test["Sex"][test["Sex"] == "male"] = 0
test["Sex"][test["Sex"] == "female"] = 1
test["Embarked"][test["Embarked"] == "S"] = 0
test["Embarked"][test["Embarked"] == "C"] = 1
test["Embarked"][test["Embarked"] == "Q"] = 2
test.Fare[152] = test.Fare.median()
test.head(10)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...

# %%
deficit_table(test)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age            0   0.000000
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        327  78.229665
# Embarked       0   0.000000

# %%
from sklearn import tree

# %%
target = train["Survived"].values
features_one = train[["Pclass", "Sex", "Age", "Fare"]].values
 
# 決定木の作成
my_tree_one = tree.DecisionTreeClassifier()
my_tree_one = my_tree_one.fit(features_one, target)
 
# 「test」の説明変数の値を取得
test_features = test[["Pclass", "Sex", "Age", "Fare"]].values
 
# 「test」の説明変数を使って「my_tree_one」のモデルで予測
my_prediction = my_tree_one.predict(test_features)
my_prediction.shape
# Out:
# (418,)

# %%
PassengerId = np.array(test["PassengerId"]).astype(int)
 
# my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
my_solution = pd.DataFrame(my_prediction, PassengerId, columns = ["Survived"])
 
# my_tree_one.csvとして書き出し
my_solution.to_csv("my_tree_one.csv", index_label = ["PassengerId"])
